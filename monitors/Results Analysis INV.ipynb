# %%
import requests
import pandas as pd
import math

# %%
account_id = "VA80685931"
access_token = "wxGlut3hLGWBQWHgwkDtT24a4Gh5"
PAPER_BASE_URL = "https://sandbox.tradier.com/v1/"

response = requests.get(f'https://sandbox.tradier.com/v1/accounts/{account_id}/gainloss',
    params={'sortBy': 'closeDate', 'sort': 'desc', 'start': '2024-04-30', 'end': '2024-05-03'},
    headers={'Authorization':f'Bearer {access_token}', 'Accept': 'application/json'}
)

json_response = response.json()
positions = json_response['gainloss']['closed_position']
df = pd.DataFrame(positions)
df['underlying'] = df.apply(lambda x: x['symbol'][:-15], axis=1)
# df = df.loc[~df['underlying'].isin(['CVX','CSCO','GM','AXP'])]
print(len(df))
# Out:
# 1505

# %%
df
# Out:
#                     close_date   cost  gain_loss  gain_loss_percent  \
# 0     2024-05-03T00:00:00.000Z  440.0     -152.0             -34.55
# 1     2024-05-03T00:00:00.000Z  304.0      528.0             173.68
# 2     2024-05-03T00:00:00.000Z   48.0      -42.0             -87.50
# 3     2024-05-03T00:00:00.000Z   48.0      -33.0             -68.75
# 4     2024-05-03T00:00:00.000Z  440.0     -154.0             -35.00
# ...                        ...    ...        ...                ...
# 1500  2024-04-30T00:00:00.000Z  139.0      -48.0             -34.53
# 1501  2024-04-30T00:00:00.000Z  119.0       20.0              16.81
# 1502  2024-04-30T00:00:00.000Z  150.0       27.0              18.00
# 1503  2024-04-30T00:00:00.000Z  114.0      -74.0             -64.91
# 1504  2024-04-30T00:00:00.000Z  357.0      266.0              74.51
#
#                      open_date  proceeds  quantity               symbol  term  \
# 0     2024-05-01T00:00:00.000Z     288.0       4.0  SBUX240503P00074000     2
# 1     2024-05-02T00:00:00.000Z     832.0      16.0   DIS240503C00113000     1
# 2     2024-05-02T00:00:00.000Z       6.0       2.0   AXP240503P00227500     1
# 3     2024-05-02T00:00:00.000Z      15.0       3.0  ORCL240503C00117000     1
# 4     2024-05-01T00:00:00.000Z     286.0      22.0  PYPL240503P00065000     2
# ...                        ...       ...       ...                  ...   ...
# 1500  2024-04-29T00:00:00.000Z      91.0       1.0     V240503C00275000     1
# 1501  2024-04-29T00:00:00.000Z     139.0       1.0    BA240503P00170000     1
# 1502  2024-04-29T00:00:00.000Z     177.0       3.0   XOM240503C00121000     1
# 1503  2024-04-29T00:00:00.000Z      40.0       2.0   NKE240503C00095000     1
# 1504  2024-04-29T00:00:00.000Z     623.0       7.0     V240503P00267500     1
#
#      underlying
# 0          SBUX
# 1           DIS
# 2           AXP
# 3          ORCL
# 4          PYPL
# ...         ...
# 1500          V
# 1501         BA
# 1502        XOM
# 1503        NKE
# 1504          V
#
# [1505 rows x 10 columns]

# %%
gain_loss = df['gain_loss'].sum()
print(f"Trading P/L: ${gain_loss}")
print(f"Trading Costs: ${math.floor(len(df)*0.70)}")
# Out:
# Trading P/L: $-2486.0
# Trading Costs: $1053

# %%
proceeds = df['proceeds'].sum()
proceeds
# Out:
# 125242.0

# %%
sorted = df.sort_values(by='gain_loss_percent', ascending=False)
sorted.head(10)
# Out:
#                    close_date   cost  gain_loss  gain_loss_percent  \
# 351  2024-05-01T00:00:00.000Z  157.0      738.0             470.06
# 412  2024-05-01T00:00:00.000Z  161.0      704.0             437.27
# 367  2024-05-01T00:00:00.000Z  130.0      468.0             360.00
# 175  2024-05-01T00:00:00.000Z  248.0      632.0             254.84
# 207  2024-05-01T00:00:00.000Z  480.0     1100.0             229.17
# 365  2024-05-01T00:00:00.000Z  448.0     1024.0             228.57
# 208  2024-05-01T00:00:00.000Z  120.0      258.0             215.00
# 198  2024-05-01T00:00:00.000Z  180.0      380.0             211.11
# 457  2024-05-01T00:00:00.000Z  240.0      490.0             204.17
# 293  2024-05-01T00:00:00.000Z  232.0      464.0             200.00
#
#                     open_date  proceeds  quantity               symbol  term  \
# 351  2024-04-30T00:00:00.000Z     895.0       1.0  SBUX240503P00086000     1
# 412  2024-04-30T00:00:00.000Z     865.0       1.0  SBUX240503P00086000     1
# 367  2024-04-30T00:00:00.000Z     598.0      26.0   CVX240503P00157500     1
# 175  2024-04-30T00:00:00.000Z     880.0       8.0   NKE240503P00091000     1
# 207  2024-04-29T00:00:00.000Z    1580.0      20.0     C240503P00061000     2
# 365  2024-04-30T00:00:00.000Z    1472.0      64.0   CVX240503P00157500     1
# 208  2024-04-30T00:00:00.000Z     378.0       6.0   XOM240503P00116000     1
# 198  2024-04-30T00:00:00.000Z     560.0       5.0   XOM240503P00117000     1
# 457  2024-04-29T00:00:00.000Z     730.0      10.0   NKE240503P00092000     2
# 293  2024-04-30T00:00:00.000Z     696.0       8.0   NKE240503P00091000     1
#
#     underlying
# 351       SBUX
# 412       SBUX
# 367        CVX
# 175        NKE
# 207          C
# 365        CVX
# 208        XOM
# 198        XOM
# 457        NKE
# 293        NKE

# %%
sorted.tail(10)
# Out:
#                    close_date   cost  gain_loss  gain_loss_percent  \
# 376  2024-05-01T00:00:00.000Z  210.0     -175.0             -83.33
# 419  2024-05-01T00:00:00.000Z  165.0     -138.0             -83.64
# 417  2024-05-01T00:00:00.000Z  174.0     -147.0             -84.48
# 452  2024-05-01T00:00:00.000Z  378.0     -324.0             -85.71
# 354  2024-05-01T00:00:00.000Z  222.0     -192.0             -86.49
# 420  2024-05-01T00:00:00.000Z  192.0     -168.0             -87.50
# 336  2024-05-01T00:00:00.000Z  282.0     -252.0             -89.36
# 428  2024-05-01T00:00:00.000Z  190.0     -180.0             -94.74
# 439  2024-05-01T00:00:00.000Z  161.0     -160.0             -99.38
# 442  2024-05-01T00:00:00.000Z  196.0     -195.0             -99.49
#
#                     open_date  proceeds  quantity               symbol  term  \
# 376  2024-04-30T00:00:00.000Z      35.0      35.0   BAC240503P00036000     1
# 419  2024-04-30T00:00:00.000Z      27.0       3.0     V240503C00275000     1
# 417  2024-04-30T00:00:00.000Z      27.0       3.0     V240503C00275000     1
# 452  2024-04-30T00:00:00.000Z      54.0       6.0     V240503C00275000     1
# 354  2024-04-30T00:00:00.000Z      30.0       6.0   JNJ240503P00144000     1
# 420  2024-04-30T00:00:00.000Z      24.0       3.0   AXP240503C00240000     1
# 336  2024-04-30T00:00:00.000Z      30.0       6.0   JNJ240503P00144000     1
# 428  2024-04-30T00:00:00.000Z      10.0      10.0   NKE240503C00095000     1
# 439  2024-04-29T00:00:00.000Z       1.0       1.0  SBUX240503C00091000     2
# 442  2024-04-29T00:00:00.000Z       1.0       1.0  SBUX240503C00090000     2
#
#     underlying
# 376        BAC
# 419          V
# 417          V
# 452          V
# 354        JNJ
# 420        AXP
# 336        JNJ
# 428        NKE
# 439       SBUX
# 442       SBUX

# %%
neg = df.loc[df['gain_loss'] < 0]
pos = df.loc[df['gain_loss'] > 0]
print(f" Number of negative sales: {len(neg)}")
print(f" Number of positive sales: {len(pos)}")
# Out:
#  Number of negative sales: 172
#  Number of positive sales: 178

# %%
pct = df['gain_loss_percent'].mean()
pct
# Out:
# -16.290853658536587

# %%
symbol = df.groupby('symbol')
symbol_pct = symbol['gain_loss_percent'].mean()
symbol_gross = symbol['gain_loss'].sum()

# %%
pd.DataFrame(symbol_pct)
# Out:
#                      gain_loss_percent
# symbol
# AAPL240419C00177500          -9.520000
# AAPL240419C00180000           4.016667
# AAPL240419C00182500         -18.750000
# ABNB240419P00155000         170.040000
# ABNB240419P00157500          61.330000
# ...                                ...
# V240419P00270000            120.830000
# V240419P00272500             92.093333
# XOM240419C00122000           -8.055000
# XOM240419C00123000           -9.635000
# XOM240419P00120000           78.130000
#
# [78 rows x 1 columns]

# %%
pd.DataFrame(symbol_gross)
# Out:
#                      gain_loss
# symbol
# AI240119P00023000        -48.0
# AI240119P00023500        -64.0
# AI240119P00024000        -88.0
# BA240119P00195000        -52.0
# BA240119P00197500        -87.0
# BA240119P00200000       -280.0
# CAT240119P00272500       -57.0
# CAT240119P00275000       -89.0
# CAT240119P00277500      -127.0
# CRWD240119P00267500      -89.0
# CRWD240119P00270000     -134.0
# CRWD240119P00272500     -203.0
# DKNG240119C00035000     1060.0
# DKNG240119C00035500      895.0
# DKNG240119C00036000      755.0
# DKNG240119P00033500      -80.0
# DKNG240119P00034000     -135.0
# DKNG240119P00034500     -220.0
# IBM240119P00162500        -2.0
# IBM240119P00165000        42.0
# INTC240119C00046500      832.0
# INTC240119C00047000      536.0
# INTC240119C00047500      320.0
# INTC240119P00044500      -80.0
# INTC240119P00045000     -144.0
# INTC240119P00045500     -240.0
# KHC240119C00038000      -308.0
# KHC240119C00038500       -88.0
# KHC240119C00039000       -22.0
# MARA240119P00016000     -150.0
# MARA240119P00016500     -210.0
# MARA240119P00017000     -264.0
# MRNA240119P00096000      -40.0
# MRNA240119P00097000      -40.0
# MRNA240119P00098000      -44.0
# PTON240119P00005500    -1000.0
# SHOP240119P00077000      -50.0
# SHOP240119P00078000      -72.0
# SHOP240119P00079000      -96.0
# SOFI240119C00007500     -220.0
# SOFI240119C00008000     -220.0
# SOFI240119P00007000     -400.0
# TDOC240119P00018000      -69.0
# TDOC240119P00018500     -115.0
# TDOC240119P00019000     -184.0
# W240119P00049000        -134.0
# W240119P00049500        -164.0
# W240119P00050000        -192.0
# ZS240119P00217500       -156.0
# ZS240119P00220000       -250.0
# ZS240119P00222500       -374.0

# %%
dff['sized_profits'] = dff.apply(lambda x: (x.sale_profit_pct/100) * 800, axis=1)

# %%
sized_profit = dff['sized_profits'].sum()
sized_profit
# Out:
# 31625.258763847472

# %%
df
# Out:
#                    close_date   cost  gain_loss  gain_loss_percent  \
# 0    2023-06-13T00:00:00.000Z  110.0      -70.0             -63.64
# 1    2023-06-13T00:00:00.000Z  110.0      -70.0             -63.64
# 2    2023-06-13T00:00:00.000Z   45.0      -31.0             -68.89
# 3    2023-06-13T00:00:00.000Z   45.0      -31.0             -68.89
# 4    2023-06-13T00:00:00.000Z   22.0      -14.0             -63.64
# ..                        ...    ...        ...                ...
# 906  2023-06-13T00:00:00.000Z   27.0       14.0              51.85
# 907  2023-06-13T00:00:00.000Z   50.0       40.0              80.00
# 908  2023-06-13T00:00:00.000Z   22.0       16.0              72.73
# 909  2023-06-13T00:00:00.000Z   22.0       18.0              81.82
# 910  2023-06-13T00:00:00.000Z   16.0        9.0              56.25
#
#                     open_date  proceeds  quantity               symbol  term
# 0    2023-06-13T00:00:00.000Z      40.0       1.0  ORCL230623C00125000     0
# 1    2023-06-13T00:00:00.000Z      40.0       1.0  ORCL230623C00125000     0
# 2    2023-06-13T00:00:00.000Z      14.0       1.0  ORCL230623C00130000     0
# 3    2023-06-13T00:00:00.000Z      14.0       1.0  ORCL230623C00130000     0
# 4    2023-06-13T00:00:00.000Z       8.0       1.0  ORCL230623C00135000     0
# ..                        ...       ...       ...                  ...   ...
# 906  2023-06-12T00:00:00.000Z      41.0       1.0  NCLH230623C00019000     1
# 907  2023-06-12T00:00:00.000Z      90.0       1.0  PLUG230623C00010500     1
# 908  2023-06-12T00:00:00.000Z      38.0       1.0  SOFI230623C00010000     1
# 909  2023-06-12T00:00:00.000Z      40.0       1.0  SOFI230623C00010000     1
# 910  2023-06-12T00:00:00.000Z      25.0       1.0  SOFI230623C00010500     1
#
# [911 rows x 9 columns]

# %%
# !ls datasets/icarus-trading-data/trader_analytics/
# Out:
# ls: cannot access 'datasets/icarus-trading-data/trader_analytics/': No such file or directory

# %%
files = !ls /datasets/icarus-trading-data/trader_analytics/2023/06

# %%
dfs = []
for filE in files:
    if filE == "01":
        continue
    data = pd.read_csv(f"/datasets/icarus-trading-data/trader_analytics/2023/06/{filE}/gross.csv")
    dfs.append(data)
df = pd.concat(dfs)

# %%
d = []
for index, row in df.iterrows():
    if "maP" in row['position_id'] or "mostactives" in row['position_id']:
        diccc = row.to_dict()
        d.append(diccc)

dff = pd.DataFrame.from_dict(d)

# %%
dff['sale_profit_gross'].sum()
# Out:
# 37973.0

# %%
dff['sale_profit_pct'].mean()
# Out:
# 11.95254707388327

# %%
df['sale_profit_gross'].sum()
# Out:
# 22931.0

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=1a301d3f-7931-43fd-93d3-efcbcf24cadb' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
